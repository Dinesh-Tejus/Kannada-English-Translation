# %%
# !pip install simpletransformers
# !pip install https://download.pytorch.org/whl/cpu/torch-1.0.1-cp36-cp36m-win_amd64.whl
# !pip install torchvision
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.5/315.5 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 35.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.1/267.1 kB 37.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 18.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 21.2 MB/s eta 0:00:00
# ...

# %%
import os
import pandas as pd
import torch

# %%
# Check if GPU is available
if torch.cuda.is_available():
    device = torch.device('cuda')
    print("Gpu")
else:
    device = torch.device('cpu')
# Out:
# Gpu

# %%
def prepare_translation_datasets():
    with open("train.trg", "r", encoding="utf-8") as f:
        kannada_text = f.readlines()
        kannada_text = [text.strip("\n") for text in kannada_text]

    with open("train.src", "r") as f:
        english_text = f.readlines()
        english_text = [text.strip("\n") for text in english_text]

    data = []
    for kannada, english in zip(kannada_text, english_text):
        data.append(["translate kannada to english", kannada, english])
        data.append(["translate english to kannada", english, kannada])

    train_df = pd.DataFrame(data, columns=["prefix", "input_text", "target_text"])

    with open("test.trg", "r", encoding="utf-8") as f:
        kannada_text = f.readlines()
        kannada_text = [text.strip("\n") for text in kannada_text]

    with open("test.src", "r") as f:
        english_text = f.readlines()
        english_text = [text.strip("\n") for text in english_text]

    data = []
    for kannada, english in zip(kannada_text, english_text):
        data.append(["translate kannada to english", kannada, english])
        data.append(["translate english to kannada", english, kannada])

    eval_df = pd.DataFrame(data, columns=["prefix", "input_text", "target_text"])

    return train_df, eval_df

# %%
train_df, eval_df = prepare_translation_datasets()

# %%
train_df
# Out:
#                                 prefix  \
# 0         translate kannada to english
# 1         translate english to kannada
# 2         translate kannada to english
# 3         translate english to kannada
# 4         translate kannada to english
# ...                                ...
# 79899463  translate english to kannada
# 79899464  translate kannada to english
# 79899465  translate english to kannada
# 79899466  translate kannada to english
# 79899467  translate english to kannada
#
#                                                  input_text  \
# 0                               ಇದಕ್ಕೆ ಪರ್ಯಾಯ ಮಾರ್ಗವೂ ಇಲ್ಲ.
# 1                           There is no alternative to it.
# 2         PayPal ನೊಂದಿಗೆ ಪಾವತಿಸುವಾಗ, ನೀವು ಪೇಪಾಲ್ ಖಾತೆಯನ್...
# 3         To pay with PayPal you don't need to create a ...
# 4                             DDoS ದಾಳಿಗೆ ಏನು ಕಾರಣವಾಗಬಹುದು?
# ...                                                     ...
# 79899463  That's if this whole thing actually gets off t...
# ...

# %%
train_df[:1000].to_csv("train_sample.tsv", sep="\t")
eval_df[:1000].to_csv("eval_sample.tsv", sep="\t")

# %%
"""train_df.to_csv("train.tsv", sep="\t")
eval_df.to_csv("eval.tsv", sep="\t")"""

# %%
import logging
import pandas as pd
from simpletransformers.t5 import T5Model, T5Args
import os
import pandas as pd
import torch


logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)

# %%
train_df = pd.read_csv("train_5L.tsv", sep="\t").astype(str)
eval_df = pd.read_csv("eval_5L.tsv", sep="\t").astype(str)

train_df["prefix"] = ""
eval_df["prefix"] = ""

# %%
#train_df.head()
#train_df.drop(columns=['Unnamed: 0','prefix'])

# %%
#eval_df.head()
#eval_df.drop(columns=['Unnamed: 0','prefix'])

# %%
# Out:
# <class 'str'>

# %%
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %%
model_args = T5Args()
model_args.max_seq_length = 96
model_args.train_batch_size = 15
model_args.eval_batch_size = 15
model_args.num_train_epochs = 1
model_args.evaluate_during_training = True
model_args.evaluate_during_training_steps = 30000
model_args.use_multiprocessing = False
model_args.fp16 = True
model_args.save_steps = -1
model_args.save_eval_checkpoints = False
model_args.no_cache = True
model_args.reprocess_input_data = True
model_args.overwrite_output_dir = True
model_args.preprocess_inputs = False
model_args.num_return_sequences = 1
model_args.wandb_project = "MT5 Kannada-English Translation"

model = T5Model("mt5", "google/mt5-base", args=model_args)

# %%
train_df = train_df[:50000]

# %%
train_df
# Out:
#       Unnamed: 0 prefix                                         input_text  \
# 0              0                               ಇದಕ್ಕೆ ಪರ್ಯಾಯ ಮಾರ್ಗವೂ ಇಲ್ಲ.
# 1              1                           There is no alternative to it.
# 2              2         PayPal ನೊಂದಿಗೆ ಪಾವತಿಸುವಾಗ, ನೀವು ಪೇಪಾಲ್ ಖಾತೆಯನ್...
# 3              3         To pay with PayPal you don't need to create a ...
# 4              4                             DDoS ದಾಳಿಗೆ ಏನು ಕಾರಣವಾಗಬಹುದು?
# ...          ...    ...                                                ...
# 49995      49995                                    Wind and sun are Free.
# 49996      49996         ನಾವು ಹಿಂದೆ ಪ್ರಸ್ತಾಪಿಸಿದ ಅಲ್ಗಾರಿದಮ್ ಅಂಟಿಕೊಳ್ಳಲು...
# 49997      49997         To do this, you will have to use the previousl...
# 49998      49998            ಸುಮಾರು 14 ವರ್ಷಗಳ ನಂತರ ರಾಘಣ್ಣ ಬಣ್ಣ ಹಚ್ಚಿದ್ದಾರೆ.
# 49999      49999                  Raviyoga is being formed after 14 years.
#
#                                              target_text
# ...

# %%
model.train_model(train_df, eval_data=eval_df)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:3892: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Epoch:   0%|          | 0/1 [00:00<?, ?it/s]
# Finishing last run (ID:9kwyvqy1) before initializing another...
# ...
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# ...

# %%
# !pip install sacrebleu
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 4.0 MB/s eta 0:00:00
# ...

# %%
import gc

gc.collect()

torch.cuda.empty_cache()

# %%
import logging
import sacrebleu
import pandas as pd
from simpletransformers.t5 import T5Model, T5Args


logging.basicConfig(level=logging.INFO)
transformers_logger = logging.getLogger("transformers")
transformers_logger.setLevel(logging.WARNING)


model_args = T5Args()
model_args.max_length = 512
model_args.length_penalty = 1
model_args.num_beams = 10
model_args.eval_batch_size = 10

model = T5Model("mt5", "outputs", args=model_args)

# %%
eval_df = pd.read_csv("eval_5L.tsv", sep="\t").astype(str)

kannada_truth = [eval_df.loc[eval_df["prefix"] == "translate english to kannada"]["target_text"].tolist()]
to_kannada = eval_df.loc[eval_df["prefix"] == "translate english to kannada"]["input_text"].tolist()

english_truth = [eval_df.loc[eval_df["prefix"] == "translate kannada to english"]["target_text"].tolist()]
to_english = eval_df.loc[eval_df["prefix"] == "translate kannada to english"]["input_text"].tolist()

# %%
# Predict
kannada_preds = model.predict(to_kannada)

eng_sin_bleu = sacrebleu.corpus_bleu(kannada_preds, kannada_truth)
print("--------------------------")
print("English to Kannada: ", eng_sin_bleu.score)

english_preds = model.predict(to_english)

sin_eng_bleu = sacrebleu.corpus_bleu(english_preds, english_truth)
print("Kannada to English: ", sin_eng_bleu.score)
# Out:
# Generating outputs:   0%|          | 0/17 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:4018: FutureWarning:
# `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of HuggingFace Transformers. Use the regular
# `__call__` method to prepare your inputs and targets.
#
# Here is a short example:
#
# model_inputs = tokenizer(src_texts, text_target=tgt_texts, ...)
#
# If you either need to use different keyword arguments for the source and target texts, you should do two calls like
# this:
#
# model_inputs = tokenizer(src_texts, ...)
# labels = tokenizer(text_target=tgt_texts, ...)
# model_inputs["labels"] = labels["input_ids"]
#
# See the documentation of your specific tokenizer for more details on the specific arguments to the tokenizer of choice.
# For a more complete example, see the implementation of `prepare_seq2seq_batch`.
#
#   warnings.warn(formatted_warning, FutureWarning)
# ...

# %%
# !nvidia-smi
# Out:
# Mon Apr 15 04:40:32 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P0              29W /  70W |  14821MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...
